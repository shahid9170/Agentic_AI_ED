# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# # Next it's time to load the API keys into environment variables
# # If this returns false, see the next cell!

# from dotenv import load_dotenv
load_dotenv(override=True)

# # Default to local Ollama if env vars are not set
# import os
# os.environ.setdefault("OPENAI_BASE_URL", "http://localhost:11434/v1")
# os.environ.setdefault("OPENAI_API_KEY", "ollama")
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-or-v1

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    # model="gpt-4.1-nano",
    model="google/gemma-3-27b-it:free",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 = 4
#
# It's a classic! 😊

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    # model="gpt-4.1-mini",
    model="qwen/qwen2.5-vl-32b-instruct:free",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# Consider the sequence of numbers defined as follows:
#
# \[ a_1 = 2, \]
# \[ a_2 = 3, \]
# \[ a_n = a_{n-1} \cdot a_{n-2} + 1 \quad \text{for} \; n \geq 3. \]
#
# Let \( S \) be the sum of the first 10 terms of this sequence. Now, define a new sequence \( b_n \) where each term is the remainder when \( a_n \) is divided by 11. Let \( T \) be the sum of the first 10 terms of the sequence \( b_n \).
#
# What is the value of \( T \)?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="google/gemma-3-27b-it:free",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# We are given the sequence $a_1 = 2$, $a_2 = 3$, and $a_n = a_{n-1} \cdot a_{n-2} + 1$ for $n \geq 3$. We want to find the sum of the first 10 terms of the sequence $b_n$, where $b_n$ is the remainder when $a_n$ is divided by 11.
#
# First, let's compute the first few terms of the sequence $a_n$:
# \begin{align*} a_1 &= 2 \\ a_2 &= 3 \\ a_3 &= a_2 \cdot a_1 + 1 = 3 \cdot 2 + 1 = 7 \\ a_4 &= a_3 \cdot a_2 + 1 = 7 \cdot 3 + 1 = 22 \\ a_5 &= a_4 \cdot a_3 + 1 = 22 \cdot 7 + 1 = 154 + 1 = 155 \\ a_6 &= a_5 \cdot a_4 + 1 = 155 \cdot 22 + 1 = 3410 + 1 = 3411 \\ a_7 &= a_6 \cdot a_5 + 1 = 3411 \cdot 155 + 1 = 528705 + 1 = 528706 \\ a_8 &= a_7 \cdot a_6 + 1 = 528706 \cdot 3411 + 1 = 1803719166 + 1 = 1803719167 \\ a_9 &= a_8 \cdot a_7 + 1 = 1803719167 \cdot 528706 + 1 = 953674289000000 + \dots + 1 \\ a_{10} &= a_9 \cdot a_8 + 1 \end{align*}
# Now, let's compute the first 10 terms of the sequence $b_n$, where $b_n \equiv a_n \pmod{11}$:
# \begin{align*} b_1 &\equiv a_1 \equiv 2 \pmod{11} \\ b_2 &\equiv a_2 \equiv 3 \pmod{11} \\ b_3 &\equiv a_3 \equiv 7 \pmod{11} \\ b_4 &\equiv a_4 \equiv 22 \equiv 0 \pmod{11} \\ b_5 &\equiv a_5 \equiv 155 \equiv 155 - 110 - 44 = 1 \pmod{11} \\ b_6 &\equiv a_6 \equiv 3411 \equiv 3411 - 3300 = 111 \equiv 111 - 110 = 1 \pmod{11} \\ b_7 &\equiv a_7 \equiv 528706 \equiv 528706 - 550000 + 21300 + 21300 - 21299 = 528706 \equiv 528706 - 480000 - 48700 + 48700 - 48699 = 528706 \equiv 528706 - 484000 - 44700 + 44699 = 528706 \equiv 528706 - 484000 - 44000 = 528706 - 528000 = 706 \equiv 706 - 660 = 46 \equiv 46 - 44 = 2 \pmod{11} \\ b_8 &\equiv a_8 \equiv 1803719167 \equiv 1803719167 \pmod{11} \end{align*}
# We can also compute the terms of $b_n$ recursively:
# \begin{align*} b_1 &= 2 \\ b_2 &= 3 \\ b_3 &= b_2 \cdot b_1 + 1 \equiv 3 \cdot 2 + 1 \equiv 7 \pmod{11} \\ b_4 &= b_3 \cdot b_2 + 1 \equiv 7 \cdot 3 + 1 \equiv 21 + 1 \equiv 22 \equiv 0 \pmod{11} \\ b_5 &= b_4 \cdot b_3 + 1 \equiv 0 \cdot 7 + 1 \equiv 1 \pmod{11} \\ b_6 &= b_5 \cdot b_4 + 1 \equiv 1 \cdot 0 + 1 \equiv 1 \pmod{11} \\ b_7 &= b_6 \cdot b_5 + 1 \equiv 1 \cdot 1 + 1 \equiv 2 \pmod{11} \\ b_8 &= b_7 \cdot b_6 + 1 \equiv 2 \cdot 1 + 1 \equiv 3 \pmod{11} \\ b_9 &= b_8 \cdot b_7 + 1 \equiv 3 \cdot 2 + 1 \equiv 7 \pmod{11} \\ b_{10} &= b_9 \cdot b_8 + 1 \equiv 7 \cdot 3 + 1 \equiv 22 \equiv 0 \pmod{11} \end{align*}
# The sequence $b_n$ is $2, 3, 7, 0, 1, 1, 2, 3, 7, 0$.
# The sum of the first 10 terms of $b_n$ is $T = 2 + 3 + 7 + 0 + 1 + 1 + 2 + 3 + 7 + 0 = 26$.
#
# Final Answer: The final answer is $\boxed{26}$

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# We are given the sequence $a_1 = 2$, $a_2 = 3$, and $a_n = a_{n-1} \cdot a_{n-2} + 1$ for $n \geq 3$. We want to find the sum of the first 10 terms of the sequence $b_n$, where $b_n$ is the remainder when $a_n$ is divided by 11.
#
# First, let's compute the first few terms of the sequence $a_n$:
# \begin{align*} a_1 &= 2 \\ a_2 &= 3 \\ a_3 &= a_2 \cdot a_1 + 1 = 3 \cdot 2 + 1 = 7 \\ a_4 &= a_3 \cdot a_2 + 1 = 7 \cdot 3 + 1 = 22 \\ a_5 &= a_4 \cdot a_3 + 1 = 22 \cdot 7 + 1 = 154 + 1 = 155 \\ a_6 &= a_5 \cdot a_4 + 1 = 155 \cdot 22 + 1 = 3410 + 1 = 3411 \\ a_7 &= a_6 \cdot a_5 + 1 = 3411 \cdot 155 + 1 = 528705 + 1 = 528706 \\ a_8 &= a_7 \cdot a_6 + 1 = 528706 \cdot 3411 + 1 = 1803719166 + 1 = 1803719167 \\ a_9 &= a_8 \cdot a_7 + 1 = 1803719167 \cdot 528706 + 1 = 953674289000000 + \dots + 1 \\ a_{10} &= a_9 \cdot a_8 + 1 \end{align*}
# Now, let's compute the first 10 terms of the sequence $b_n$, where $b_n \equiv a_n \pmod{11}$:
# \begin{align*} b_1 &\equiv a_1 \equiv 2 \pmod{11} \\ b_2 &\equiv a_2 \equiv 3 \pmod{11} \\ b_3 &\equiv a_3 \equiv 7 \pmod{11} \\ b_4 &\equiv a_4 \equiv 22 \equiv 0 \pmod{11} \\ b_5 &\equiv a_5 \equiv 155 \equiv 155 - 110 - 44 = 1 \pmod{11} \\ b_6 &\equiv a_6 \equiv 3411 \equiv 3411 - 3300 = 111 \equiv 111 - 110 = 1 \pmod{11} \\ b_7 &\equiv a_7 \equiv 528706 \equiv 528706 - 550000 + 21300 + 21300 - 21299 = 528706 \equiv 528706 - 480000 - 48700 + 48700 - 48699 = 528706 \equiv 528706 - 484000 - 44700 + 44699 = 528706 \equiv 528706 - 484000 - 44000 = 528706 - 528000 = 706 \equiv 706 - 660 = 46 \equiv 46 - 44 = 2 \pmod{11} \\ b_8 &\equiv a_8 \equiv 1803719167 \equiv 1803719167 \pmod{11} \end{align*}
# We can also compute the terms of $b_n$ recursively:
# \begin{align*} b_1 &= 2 \\ b_2 &= 3 \\ b_3 &= b_2 \cdot b_1 + 1 \equiv 3 \cdot 2 + 1 \equiv 7 \pmod{11} \\ b_4 &= b_3 \cdot b_2 + 1 \equiv 7 \cdot 3 + 1 \equiv 21 + 1 \equiv 22 \equiv 0 \pmod{11} \\ b_5 &= b_4 \cdot b_3 + 1 \equiv 0 \cdot 7 + 1 \equiv 1 \pmod{11} \\ b_6 &= b_5 \cdot b_4 + 1 \equiv 1 \cdot 0 + 1 \equiv 1 \pmod{11} \\ b_7 &= b_6 \cdot b_5 + 1 \equiv 1 \cdot 1 + 1 \equiv 2 \pmod{11} \\ b_8 &= b_7 \cdot b_6 + 1 \equiv 2 \cdot 1 + 1 \equiv 3 \pmod{11} \\ b_9 &= b_8 \cdot b_7 + 1 \equiv 3 \cdot 2 + 1 \equiv 7 \pmod{11} \\ b_{10} &= b_9 \cdot b_8 + 1 \equiv 7 \cdot 3 + 1 \equiv 22 \equiv 0 \pmod{11} \end{align*}
# The sequence $b_n$ is $2, 3, 7, 0, 1, 1, 2, 3, 7, 0$.
# The sum of the first 10 terms of $b_n$ is $T = 2 + 3 + 7 + 0 + 1 + 1 + 2 + 3 + 7 + 0 = 26$.
#
# Final Answer: The final answer is $\boxed{26}$

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "pick a business area that might be worth exploring for an Agentic AI opportunity"}]

# Then make the first call:

response = openai.chat.completions.create(
    model="google/gemma-3-27b-it:free",
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content

print(business_idea)

# And repeat! In the next message, include the business idea within the message
# Out:
# Okay, let's explore **Personalized Education/Tutoring** as a potentially lucrative area for Agentic AI. Here's a breakdown of why, the opportunity, how Agentic AI could be applied, potential challenges, and a bit on market size:
#
# **1. Why Personalized Education/Tutoring?**
#
# * **High Demand:**  The need for personalized learning is *huge*. Traditional education often struggles to cater to individual learning styles, paces, and knowledge gaps.  Parents are increasingly willing to invest in supplemental education.
# * **Data Rich:** Education generates a lot of data – student performance, learning patterns, areas of struggle, preferred learning methods. This data is *fuel* for AI.
# * **Relatively Low Risk (compared to, say, healthcare):** Mistakes in tutoring, while undesirable, generally have lower stakes than errors in medical diagnosis. This allows for more rapid iteration and experimentation.
# * **Scalability:**  AI-powered tutoring can scale far more easily than hiring human tutors for everyone who needs one.
# * **Current Solutions are Limited:** Existing online tutoring platforms often rely on pre-scripted content or connecting students with human tutors, lacking true *adaptability* and *proactive* support.
#
#
#
# **2. The Opportunity: Agentic AI Tutoring - "The Proactive Learning Companion"**
#
# Instead of just *responding* to student questions (like current chatbots), an Agentic AI tutor would:
#
# * **Proactively Assess:** Continuously monitor student performance, identify knowledge gaps *before* they become major problems, and diagnose learning style preferences.
# * **Curriculum Adaptation:**  Dynamically adjust the learning path, content difficulty, and teaching methods based on the student's needs.  This goes beyond simple "adaptive learning" – it's about *creating* a unique curriculum.
# * **Multi-Modal Learning:**  Utilize various learning modalities – text, video, interactive simulations, practice problems – and switch between them based on what's most effective for the student.
# * **Goal Setting & Motivation:** Help students set realistic goals, track progress, and provide encouragement.  Could even integrate with reward systems.
# * **Metacognitive Support:**  Teach students *how* to learn – strategies for problem-solving, note-taking, time management, and self-assessment.
# * **Long-Term Learning Profile:** Build a comprehensive learning profile for each student, tracking their progress over time and identifying areas for continued growth.
# * **Integration with Existing Systems:** Connect with school learning management systems (LMS) to supplement classroom learning.
#
#
#
#
# **3. How Agentic AI Would Be Applied (Key Components)**
#
# * **Large Language Models (LLMs):**  Foundation for natural language understanding, content generation, and conversational interaction. (GPT-4, Gemini, Claude)
# * **Reinforcement Learning (RL):**  To optimize the learning path and teaching strategies based on student responses and performance.  The AI learns what works best for each student.
# * **Knowledge Graph:**  A structured representation of the subject matter, allowing the AI to understand relationships between concepts and identify relevant learning materials.
# * **Student Modeling:**  Sophisticated models to represent each student's knowledge, skills, learning style, and motivation.  This is *crucial* for personalization.
# * **Planning & Reasoning:**  The "agency" part.  The AI needs to be able to plan a sequence of learning activities, reason about the student's needs, and adapt its plan as needed.  (Tools like AutoGPT, LangChain, or CrewAI would be relevant here).
# * **Tool Use:**  The AI could use external tools like:
#     * **Wolfram Alpha:** For complex calculations and data analysis.
#     * **Desmos/GeoGebra:** For interactive math and science visualizations.
#     * **YouTube API:** To find relevant educational videos.
#     * **Content Creation Tools:** To generate custom practice problems or explanations.
# * **Memory & Context Management:**  Essential for maintaining a coherent conversation and remembering the student's past performance.
#
#
#
#
# **4. Potential Challenges**
#
# * **Hallucinations & Accuracy:** LLMs can sometimes generate incorrect or misleading information.  Rigorous fact-checking and validation are essential.
# * **Bias:**  AI models can inherit biases from the data they are trained on.  Care must be taken to ensure fairness and equity.
# * **Explainability:**  It's important to understand *why* the AI is making certain recommendations.  Black-box AI can be difficult to trust.
# * **Data Privacy:**  Protecting student data is paramount.  Compliance with privacy regulations (e.g., COPPA, GDPR) is essential.
# * **Emotional Intelligence:**  AI currently lacks the emotional intelligence of a human tutor.  It may struggle to provide the same level of empathy and support.
# * **Cost of Development & Maintenance:** Building and maintaining a sophisticated Agentic AI system is expensive.
#
#
#
#
# **5. Market Size & Potential**
#
# * **Global E-Learning Market:**  Projected to reach $325 billion by 2025 (Source: Global Market Insights).
# * **Online Tutoring Market:** A significant portion of the e-learning market, growing rapidly.  Estimated at $6.6 billion in 2023 and projected to reach $13.2 billion by 2030 (Source: Fortune Business Insights).
# * **Premium Pricing:**  Personalized, Agentic AI tutoring could command a premium price compared to traditional online tutoring.  Subscription models are likely.
# * **Target Markets:**
#     * **K-12 Students:**  Supplemental learning, test preparation.
#     * **College Students:**  Support for challenging courses.
#     * **Adult Learners:**  Skill development, career advancement.
#
#
#
#
# **Example Scenario:**
#
# A student is struggling with algebra.  The Agentic AI tutor:
#
# 1. **Detects the struggle:**  Through analyzing incorrect answers on practice problems.
# 2. **Diagnoses the root cause:**  Identifies a weakness in understanding fractions.
# 3. **Proactively intervenes:**  Doesn't just offer more algebra problems, but *creates* a mini-lesson on fractions, using interactive visualizations and real-world examples.
# 4. **Adapts to learning style:**  If the student responds well to visual learning, it incorporates more diagrams and videos.
# 5. **Provides encouragement:**  Offers positive feedback and celebrates small victories.
# 6. **Long-term tracking:**  Records the student's progress and adjusts the learning path accordingly.
#
#
#
#
# **In conclusion:**  Personalized Education/Tutoring is a compelling area for Agentic AI.  While challenges exist, the potential benefits – improved learning outcomes, increased access to education, and scalable personalization – are significant.  It's a space ripe for innovation.
#
#
#
# Do you want me to dive deeper into any specific aspect of this, like the technical architecture, potential business models, or competitive landscape?  Or would you like me to explore a different business area?

# %%
messages = [{"role": "user", "content": business_idea}]

response = openai.chat.completions.create(
    model= "qwen/qwen2.5-vl-32b-instruct:free"
    massage = business_idea
)
